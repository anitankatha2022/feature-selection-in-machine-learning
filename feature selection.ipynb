# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data=pd.read_csv('C:\\Users\\USER\\Desktop\\ESSY\\scores.csv')
originalfeatures=data.columns
print('originalfeatures count',len(originalfeatures))
print('originalfeatures',originalfeatures)
print(data.head())
# Out:
# originalfeatures count 6
# originalfeatures Index(['Python', 'Sql', 'ML', 'Tableau', 'Excel', 'Student Placed'], dtype='object')
#    Python   Sql    ML  Tableau  Excel Student Placed
# 0    0.80  0.57  0.63     0.50   0.34            Yes
# 1    0.81  0.90  0.62     0.71   0.92             No
# 2    0.49  0.69  0.62     0.64   0.41             No
# 3    0.40  0.94  0.60     0.26   0.47             No
# 4    0.31  0.87  1.00     0.23   0.99             No

# %%
alpha=0.02
plt.figure(figsize=(10,10))

plt.subplot(121)
plt.scatter(data. Python ,data.Sql,color='blue',alpha=alpha)
plt.title(' Number')
plt.subplot(122)
plt.scatter(data.ML,data.Excel,color='green',alpha=alpha)
plt.title('ML,Excel')
# Out:
# Text(0.5, 1.0, 'ML,Excel')
